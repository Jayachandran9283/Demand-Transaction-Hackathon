# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder,StandardScaler,minmax_scale
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.naive_bayes import GaussianNB,BernoulliNB
import statsmodels.api as sns
from sklearn.metrics import classification_report,accuracy_score,precision_score,recall_score,confusion_matrix,roc_auc_score,plot_roc_curve,f1_score

# %%
df=pd.read_csv(r'C:\Users\jayac\Downloads\Dataset\Demand_txn.csv',index_col=0)

# %%
df.head()
# Out:
#         City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0  Hyderabad         Take Away              9978       2018-07-31
# 1  Hyderabad         Take Away              4064       2018-07-31
# 2  Hyderabad         Main Hall               965       2018-07-31
# 3  Hyderabad           Express              9978       2018-07-31
# 4  Hyderabad           Express              1045       2018-07-31
#
#    Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 0            167         187.0                 0.05       163.700000
# 1            368         602.0                 0.05       584.329105
# 2            694         263.0                 0.05       244.835163
# 3            140         263.0                 0.05       243.500000
# 4            139         392.0                 0.05       378.960000
#
#    Percent_Quantity_With_Discount  Avg_Discount_Percent_On_Discounted_Items  \
# ...

# %%
df.dtypes
# Out:
# City                                           object
# Mapped_Sales_Type                              object
# Mapped_Item_Code                                int64
# Transaction_Date                               object
# Quantity_Sold                                   int64
# Median_Price                                  float64
# Average_Tax_Percent                           float64
# Effective_Price                               float64
# Percent_Quantity_With_Discount                float64
# Avg_Discount_Percent_On_Discounted_Items      float64
# Year                                            int64
# Month                                           int64
# Day                                            object
# Car_sales                                     float64
# F_and_B_Inflation                             float64
# F_and_B_Inflation_Adjusted_Effective_Price    float64
# F_and_B_Inflation_Adjusted_Median_Price       float64
# ...

# %%
df['City'].unique()
# Out:
# array(['Hyderabad'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30231 entries, 0 to 30230
# Data columns (total 22 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   City                                        30231 non-null  object
#  1   Mapped_Sales_Type                           30231 non-null  object
#  2   Mapped_Item_Code                            30231 non-null  int64
#  3   Transaction_Date                            30231 non-null  object
#  4   Quantity_Sold                               30231 non-null  int64
#  5   Median_Price                                30231 non-null  float64
#  6   Average_Tax_Percent                         30231 non-null  float64
#  7   Effective_Price                             30229 non-null  float64
#  8   Percent_Quantity_With_Discount              12209 non-null  float64
# ...

# %%
df['Mapped_Sales_Type'].value_counts()
# Out:
# Take Away    9812
# Delivery     9469
# Dine-in      5271
# Main Hall    3529
# Express      2061
# Bakery         89
# Name: Mapped_Sales_Type, dtype: int64

# %%
df['Mapped_Item_Code'].unique()
# Out:
# array([ 9978,  4064,   965,  1045,  4056,  4065,  4058,  4057,  4061,
#         4055,   979,  4066,   978,  4062,   971,   970,   966,  4068,
#         4063,   964,  4060, 10000,  4059], dtype=int64)

# %%
df['Effective_Price'].isna().sum()
# Out:
# 2

# %%
df['Effective_Price'].fillna(df['Effective_Price'].mean(),inplace=True)

# %%
df['Percent_Quantity_With_Discount'].unique()
# Out:
# array([       nan, 0.02723735, 0.00395257, ..., 0.03950617, 0.01017812,
#        0.00933786])

# %%
df['Mapped_Item_Code'] = df['Mapped_Item_Code'].astype(str)

# %%
df['Transaction_Date'] = pd.to_datetime(df['Transaction_Date'])

# %%
df['Transaction_Date'].min()
# Out:
# Timestamp('2016-08-01 00:00:00')

# %%
df = df.loc[(df['Transaction_Date'] >= '2016-08-01'), :]

# %%
df.columns
# Out:
# Index(['City', 'Mapped_Sales_Type', 'Mapped_Item_Code', 'Transaction_Date',
#        'Quantity_Sold', 'Median_Price', 'Average_Tax_Percent',
#        'Effective_Price', 'Percent_Quantity_With_Discount',
#        'Avg_Discount_Percent_On_Discounted_Items', 'Year', 'Month', 'Day',
#        'Car_sales', 'F_and_B_Inflation',
#        'F_and_B_Inflation_Adjusted_Effective_Price',
#        'F_and_B_Inflation_Adjusted_Median_Price',
#        'First_Week_Of_The_Month_Dummy', 'Last_Week_Of_The_Month_Dummy',
#        'Day_Of_The_Week_Seasonality', 'Month_Of_The_Year_Seasonality',
#        'Two_Wheeler_sales'],
#       dtype='object')

# %%
df['Mapped_Sales_Type'].unique()
# Out:
# array(['Take Away', 'Main Hall', 'Express', 'Delivery', 'Dine-in',
#        'Bakery'], dtype=object)

# %%
# df['Avg_Discount_Percent_On_Discounted_Items'] = np.where(df['P*Q'].notnull(), (df['Discount_Amount']/df['P*Q'])*df['Tax%'] , np.nan )

# %%
df = df.loc[df['Avg_Discount_Percent_On_Discounted_Items'] < 1.0, :]

# %%
df.loc[df['Avg_Discount_Percent_On_Discounted_Items'] >= 1.0]
# Out:
# Empty DataFrame
# Columns: [City, Mapped_Sales_Type, Mapped_Item_Code, Transaction_Date, Quantity_Sold, Median_Price, Average_Tax_Percent, Effective_Price, Percent_Quantity_With_Discount, Avg_Discount_Percent_On_Discounted_Items, Year, Month, Day, Car_sales, F_and_B_Inflation, F_and_B_Inflation_Adjusted_Effective_Price, F_and_B_Inflation_Adjusted_Median_Price, First_Week_Of_The_Month_Dummy, Last_Week_Of_The_Month_Dummy, Day_Of_The_Week_Seasonality, Month_Of_The_Year_Seasonality, Two_Wheeler_sales]
# Index: []
#
# [0 rows x 22 columns]

# %%
dict_aggr1 = {'Quantity_Sold':'sum', 'Median_Price':'median', 'Effective_Price':'median'}

# %%
df_agg = df.groupby(['City', 'Mapped_Sales_Type', 'Mapped_Item_Code', 'Transaction_Date']).agg(dict_aggr1).reset_index()

# %%
df_agg[:3]
# Out:
#         City Mapped_Sales_Type Mapped_Item_Code Transaction_Date  \
# 0  Hyderabad            Bakery             4059       2018-06-14
# 1  Hyderabad            Bakery             4060       2018-06-14
# 2  Hyderabad            Bakery             4063       2018-06-14
#
#    Quantity_Sold  Median_Price  Effective_Price
# 0            109         359.0           314.27
# 1            110         378.0           332.22
# 2            110         732.0           666.76

# %%
df.loc[df['Median_Price'].isnull()]
# Out:
# Empty DataFrame
# Columns: [City, Mapped_Sales_Type, Mapped_Item_Code, Transaction_Date, Quantity_Sold, Median_Price, Average_Tax_Percent, Effective_Price, Percent_Quantity_With_Discount, Avg_Discount_Percent_On_Discounted_Items, Year, Month, Day, Car_sales, F_and_B_Inflation, F_and_B_Inflation_Adjusted_Effective_Price, F_and_B_Inflation_Adjusted_Median_Price, First_Week_Of_The_Month_Dummy, Last_Week_Of_The_Month_Dummy, Day_Of_The_Week_Seasonality, Month_Of_The_Year_Seasonality, Two_Wheeler_sales]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.loc[df['Effective_Price'].notnull()].head()
# Out:
#          City Mapped_Sales_Type Mapped_Item_Code Transaction_Date  \
# 5   Hyderabad          Delivery             4056       2018-07-31
# 10  Hyderabad          Delivery             4061       2018-07-31
# 20  Hyderabad           Dine-in              966       2018-07-31
# 24  Hyderabad           Dine-in              965       2018-07-31
# 26  Hyderabad          Delivery             4068       2018-07-31
#
#     Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 5             617         322.0                 0.05       305.354585
# 10            144         942.0                 0.05       942.631515
# 20           1250         392.0                 0.05       378.840053
# 24           1934         362.0                 0.05       347.258327
# 26            148         622.0                 0.05       618.898649
#
#     Percent_Quantity_With_Discount  Avg_Discount_Percent_On_Discounted_Items  \
# ...

# %%
df.loc[(df['City'] == 'Hyderabad') & (df['Mapped_Sales_Type'] == 'Delivery'), :].head()
# Out:
#          City Mapped_Sales_Type Mapped_Item_Code Transaction_Date  \
# 5   Hyderabad          Delivery             4056       2018-07-31
# 10  Hyderabad          Delivery             4061       2018-07-31
# 26  Hyderabad          Delivery             4068       2018-07-31
# 42  Hyderabad          Delivery             4058       2018-07-31
# 46  Hyderabad          Delivery             4064       2018-07-31
#
#     Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 5             617         322.0                 0.05       305.354585
# 10            144         942.0                 0.05       942.631515
# 26            148         622.0                 0.05       618.898649
# 42            532         272.0                 0.05       252.660214
# 46            261         682.0                 0.05       683.031933
#
#     Percent_Quantity_With_Discount  Avg_Discount_Percent_On_Discounted_Items  \
# ...

# %%
df.loc[df['Day'].isin(['Mon', 'Tue']), :].head()
# Out:
#          City Mapped_Sales_Type Mapped_Item_Code Transaction_Date  \
# 5   Hyderabad          Delivery             4056       2018-07-31
# 10  Hyderabad          Delivery             4061       2018-07-31
# 20  Hyderabad           Dine-in              966       2018-07-31
# 24  Hyderabad           Dine-in              965       2018-07-31
# 26  Hyderabad          Delivery             4068       2018-07-31
#
#     Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 5             617         322.0                 0.05       305.354585
# 10            144         942.0                 0.05       942.631515
# 20           1250         392.0                 0.05       378.840053
# 24           1934         362.0                 0.05       347.258327
# 26            148         622.0                 0.05       618.898649
#
#     Percent_Quantity_With_Discount  Avg_Discount_Percent_On_Discounted_Items  \
# ...

# %%
df.loc[df['Percent_Quantity_With_Discount'] != 0.0, :].head()
# Out:
#          City Mapped_Sales_Type Mapped_Item_Code Transaction_Date  \
# 5   Hyderabad          Delivery             4056       2018-07-31
# 10  Hyderabad          Delivery             4061       2018-07-31
# 20  Hyderabad           Dine-in              966       2018-07-31
# 24  Hyderabad           Dine-in              965       2018-07-31
# 26  Hyderabad          Delivery             4068       2018-07-31
#
#     Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 5             617         322.0                 0.05       305.354585
# 10            144         942.0                 0.05       942.631515
# 20           1250         392.0                 0.05       378.840053
# 24           1934         362.0                 0.05       347.258327
# 26            148         622.0                 0.05       618.898649
#
#     Percent_Quantity_With_Discount  Avg_Discount_Percent_On_Discounted_Items  \
# ...

# %%
df.columns
# Out:
# Index(['City', 'Mapped_Sales_Type', 'Mapped_Item_Code', 'Transaction_Date',
#        'Quantity_Sold', 'Median_Price', 'Average_Tax_Percent',
#        'Effective_Price', 'Percent_Quantity_With_Discount',
#        'Avg_Discount_Percent_On_Discounted_Items', 'Year', 'Month', 'Day',
#        'Car_sales', 'F_and_B_Inflation',
#        'F_and_B_Inflation_Adjusted_Effective_Price',
#        'F_and_B_Inflation_Adjusted_Median_Price',
#        'First_Week_Of_The_Month_Dummy', 'Last_Week_Of_The_Month_Dummy',
#        'Day_Of_The_Week_Seasonality', 'Month_Of_The_Year_Seasonality',
#        'Two_Wheeler_sales'],
#       dtype='object')

# %%
df['Range'] = np.where(df['Effective_Price']>500, 1, 0.5)

# %%
df.head()
# Out:
#          City Mapped_Sales_Type Mapped_Item_Code Transaction_Date  \
# 5   Hyderabad          Delivery             4056       2018-07-31
# 10  Hyderabad          Delivery             4061       2018-07-31
# 20  Hyderabad           Dine-in              966       2018-07-31
# 24  Hyderabad           Dine-in              965       2018-07-31
# 26  Hyderabad          Delivery             4068       2018-07-31
#
#     Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 5             617         322.0                 0.05       305.354585
# 10            144         942.0                 0.05       942.631515
# 20           1250         392.0                 0.05       378.840053
# 24           1934         362.0                 0.05       347.258327
# 26            148         622.0                 0.05       618.898649
#
#     Percent_Quantity_With_Discount  Avg_Discount_Percent_On_Discounted_Items  \
# ...

# %%
df.columns
# Out:
# Index(['City', 'Mapped_Sales_Type', 'Mapped_Item_Code', 'Transaction_Date',
#        'Quantity_Sold', 'Median_Price', 'Average_Tax_Percent',
#        'Effective_Price', 'Percent_Quantity_With_Discount',
#        'Avg_Discount_Percent_On_Discounted_Items', 'Year', 'Month', 'Day',
#        'Car_sales', 'F_and_B_Inflation',
#        'F_and_B_Inflation_Adjusted_Effective_Price',
#        'F_and_B_Inflation_Adjusted_Median_Price',
#        'First_Week_Of_The_Month_Dummy', 'Last_Week_Of_The_Month_Dummy',
#        'Day_Of_The_Week_Seasonality', 'Month_Of_The_Year_Seasonality',
#        'Two_Wheeler_sales', 'Range'],
#       dtype='object')

# %%
x = df[['Mapped_Item_Code', 'Median_Price', 'Average_Tax_Percent',
       'Effective_Price', 'Percent_Quantity_With_Discount',
       'Avg_Discount_Percent_On_Discounted_Items','Car_sales', 'F_and_B_Inflation',
       'F_and_B_Inflation_Adjusted_Effective_Price',
       'F_and_B_Inflation_Adjusted_Median_Price']]

# %%
y= df['Quantity_Sold']

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size = 0.3, random_state = 123)

# %%
lr = LinearRegression()

# %%
lr.fit(train_x, train_y)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(train_x)

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(train_y, y_pred)
# Out:
# 325.3970905975991

# %%
#Ordinary least squares

# %%
import statsmodels.formula.api as sm

# %%
ols_output = sns.OLS(y, x.astype(float)).fit()

# %%
ols_output.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          Quantity_Sold   R-squared (uncentered):                   0.739
# Model:                            OLS   Adj. R-squared (uncentered):              0.739
# Method:                 Least Squares   F-statistic:                              2519.
# Date:                Thu, 08 Apr 2021   Prob (F-statistic):                        0.00
# Time:                        11:15:47   Log-Likelihood:                         -67530.
# No. Observations:                8902   AIC:                                  1.351e+05
# Df Residuals:                    8892   BIC:                                  1.352e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                                                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
x.head()
# Out:
#    Mapped_Item_Code  Median_Price  Average_Tax_Percent  Effective_Price  \
# 5              4056         322.0                 0.05       305.354585
# 10             4061         942.0                 0.05       942.631515
# 20              966         392.0                 0.05       378.840053
# 24              965         362.0                 0.05       347.258327
# 26             4068         622.0                 0.05       618.898649
#
#     Percent_Quantity_With_Discount  Avg_Discount_Percent_On_Discounted_Items  \
# 5                         0.003953                                  0.105020
# 10                        0.151515                                  0.105006
# 20                        0.003512                                  0.105008
# 24                        0.001646                                  0.420000
# 26                        0.027027                                  0.105009
#
# ...

# %%
def KNN_predict(train_x,test_x,train_y,test_y,scaler,k_value,metric='manhattan',weights='uniform'):
    scaled_train=scaler.fit_transform(train_x,train_y)
    scaled_test=scaler.transform(test_x)
    KNN= KNeighborsRegressor(n_neighbors=k_value,weights=weights,metric=metric)
    KNN.fit(scaled_train,train_y)
    pred_train=KNN.predict(scaled_train)
    pred_test=KNN.predict(scaled_test)
    print(f'Rsquare of Train {round(KNN.score(scaled_train, train_y) , 2)}')
    print(f'Rsquare of Test {round(KNN.score(scaled_test, test_y) , 2)}')
    #print(f'MAE {metrics.mean_absolute_error(train_y, pred_train)}')
    return KNN_predict

# %%
KNN_predict(train_x, test_x, train_y,test_y,StandardScaler(),1)
# Out:
# Rsquare of Train 1.0
# Rsquare of Test 0.7
# <function __main__.KNN_predict(train_x, test_x, train_y, test_y, scaler, k_value, metric='manhattan', weights='uniform')>

# %%
for k in range(1, 11):
    print('R square on KNN using n_neighbors = {0}:'.format(k), end = ' ')
    KNN_predict(train_x, test_x, train_y,test_y,StandardScaler(), k)
# Out:
# R square on KNN using n_neighbors = 1: Rsquare of Train 1.0
# Rsquare of Test 0.7
# R square on KNN using n_neighbors = 2: Rsquare of Train 0.92
# Rsquare of Test 0.76
# R square on KNN using n_neighbors = 3: Rsquare of Train 0.89
# Rsquare of Test 0.77
# R square on KNN using n_neighbors = 4: Rsquare of Train 0.87
# Rsquare of Test 0.76
# R square on KNN using n_neighbors = 5: Rsquare of Train 0.85
# Rsquare of Test 0.76
# R square on KNN using n_neighbors = 6: Rsquare of Train 0.83
# Rsquare of Test 0.75
# R square on KNN using n_neighbors = 7: Rsquare of Train 0.82
# Rsquare of Test 0.75
# R square on KNN using n_neighbors = 8: Rsquare of Train 0.81
# Rsquare of Test 0.74
# R square on KNN using n_neighbors = 9: Rsquare of Train 0.8
# Rsquare of Test 0.74
# R square on KNN using n_neighbors = 10: Rsquare of Train 0.79
# Rsquare of Test 0.74

# %%
k=4
for metric in ['euclidean','minkowski','manhattan','chebyshev']:
    print('R square on {0} metrics \n'.format(metric),end=' ')
    KNN_predict(train_x, test_x, train_y,test_y, StandardScaler(), k,metric,weights='uniform')
# Out:
# R square on euclidean metrics
#  Rsquare of Train 0.82
# Rsquare of Test 0.66
# R square on minkowski metrics
#  Rsquare of Train 0.82
# Rsquare of Test 0.66
# R square on manhattan metrics
#  Rsquare of Train 0.87
# Rsquare of Test 0.76
# R square on chebyshev metrics
#  Rsquare of Train 0.76
# Rsquare of Test 0.58

# %%
for weight in ['uniform','distance']:
    print('R square on {0} weights \n'.format(weight),end=' ')
    KNN_predict(train_x, test_x, train_y,test_y, StandardScaler(), k_value=4,metric='manhattan',weights=weight)
# Out:
# R square on uniform weights
#  Rsquare of Train 0.87
# Rsquare of Test 0.76
# R square on distance weights
#  Rsquare of Train 1.0
# Rsquare of Test 0.78

# %%
scaler=StandardScaler()

# %%
scaled_train_x=scaler.fit_transform(train_x)
scaled_test_x=scaler.transform(test_x)
KNN= KNeighborsRegressor(n_neighbors=4,weights='uniform',metric='manhattan')
KNN.fit(scaled_train_x,train_y)
pred_train=KNN.predict(scaled_train_x)
pred_test=KNN.predict(scaled_test_x)
print(f'rsquare {KNN.score(scaled_train_x,train_y)}')
print(f'rsquare {KNN.score(scaled_test_x,test_y)}')
print(f'MAE {metrics.mean_absolute_error(train_y, pred_train)}')
print(f'MAE {metrics.mean_absolute_error(test_y, pred_test)}')
# Out:
# rsquare 0.8651931596981273
# rsquare 0.7643185320861047
# MAE 137.39082811747713
# MAE 175.44290527892176
